# %% [markdown]
# ##### LOAD THE DATA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

X = pd.read_csv('monthly-milk-production-pounds-p.csv', header=0, names=['month', 'ppc'])

plt.plot(X.ppc);
X.head()
# Out:
#      month    ppc
# 0  1962-01  589.0
# 1  1962-02  561.0
# 2  1962-03  640.0
# 3  1962-04  656.0
# 4  1962-05  727.0
